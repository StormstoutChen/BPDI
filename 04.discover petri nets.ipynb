# %%
from pm4py.objects.log.importer.xes import importer as xes_importer
import pm4py
import pandas as pd

# %%
path = "./"

# %%
# These lines reads the log file
log_file1 = '2019LogWithoutLifecycle.xes'
log_file2 = '2020WithBeginAndEndDuplicatedWithoutLifecycle.xes'

# %%
log1 = xes_importer.apply(path + log_file1)
log2 = xes_importer.apply(path + log_file2)
# Out:
# c:\workspace\.venv\lib\site-packages\pm4py\util\dt_parsing\parser.py:77: UserWarning: ISO8601 strings are not fully supported with strpfromiso for Python versions below 3.11
#   "ISO8601 strings are not fully supported with strpfromiso for Python versions below 3.11")
# ...
# parsing log, completed traces ::   0%|          | 0/1998 [00:00<?, ?it/s]

# %%
net2, im2, fm2 = pm4py.discover_petri_net_alpha(log2)
pm4py.view_petri_net(net2, im2, fm2)
# Out:
# c:\workspace\.venv\lib\site-packages\pm4py\utils.py:486: UserWarning: the EventLog class has been deprecated and will be removed in a future release.
#   warnings.warn("the EventLog class has been deprecated and will be removed in a future release.")

# %%
net2, im2, fm2 = pm4py.discover_petri_net_heuristics(log2, dependency_threshold=0.99)
pm4py.view_petri_net(net2, im2, fm2)

# %%
tree2 = pm4py.discover_process_tree_inductive(log2)
net2, im2, fm2 = pm4py.convert_to_petri_net(tree2)
pm4py.view_petri_net(net2, im2, fm2)

# %%
tree2 = pm4py.discover_process_tree_inductive(log2)
bpmn_graph2 = pm4py.convert_to_bpmn(tree2)
pm4py.view_bpmn(bpmn_graph2)

# %%
tree1 = pm4py.discover_process_tree_inductive(log1)
bpmn_graph1 = pm4py.convert_to_bpmn(tree1)
pm4py.view_bpmn(bpmn_graph1)
